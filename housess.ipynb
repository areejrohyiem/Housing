# %% [markdown]
# <a href="https://www.kaggle.com/code/areejrohyiem/housess?scriptVersionId=168478455" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv('/kaggle/input/housesalesprediction/kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id                           date         price  \
# count  2.161300e+04                          21613  2.161300e+04
# mean   4.580302e+09  2014-10-29 04:38:01.959931648  5.400881e+05
# min    1.000102e+06            2014-05-02 00:00:00  7.500000e+04
# 25%    2.123049e+09            2014-07-22 00:00:00  3.219500e+05
# 50%    3.904930e+09            2014-10-16 00:00:00  4.500000e+05
# 75%    7.308900e+09            2015-02-17 00:00:00  6.450000e+05
# max    9.900000e+09            2015-05-27 00:00:00  7.700000e+06
# std    2.876566e+09                            NaN  3.671272e+05
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21613.000000  21613.000000  21613.000000  2.161300e+04  21613.000000
# mean       3.370842      2.114757   2079.899736  1.510697e+04      1.494309
# min        0.000000      0.000000    290.000000  5.200000e+02      1.000000
# ...

# %%
corr=df.corr()
corr
# Out:
#                      id      date     price  bedrooms  bathrooms  sqft_living  \
# id             1.000000  0.005577 -0.016762  0.001286   0.005160    -0.012258
# date           0.005577  1.000000 -0.004357 -0.016800  -0.034410    -0.034559
# price         -0.016762 -0.004357  1.000000  0.308350   0.525138     0.702035
# bedrooms       0.001286 -0.016800  0.308350  1.000000   0.515884     0.576671
# bathrooms      0.005160 -0.034410  0.525138  0.515884   1.000000     0.754665
# sqft_living   -0.012258 -0.034559  0.702035  0.576671   0.754665     1.000000
# sqft_lot      -0.132109  0.006313  0.089661  0.031703   0.087740     0.172826
# floors         0.018525 -0.022491  0.256794  0.175429   0.500653     0.353949
# waterfront    -0.002721  0.001356  0.266369 -0.006582   0.063744     0.103818
# view           0.011592 -0.001800  0.397293  0.079532   0.187737     0.284611
# condition     -0.023783 -0.050769  0.036362  0.028472  -0.124982    -0.058753
# ...

# %%
df['price'].corr(df['yr_built'])
# Out:
# 0.05401153149479269

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df['price'].corr(df['bathrooms'])
# Out:
# 0.525137505413962

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
df.drop(columns=['id','date','long','zipcode','condition'], axis=1, inplace = True)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  grade  sqft_above  sqft_basement  yr_built  \
# 0               0     0      7        1180              0      1955
# ...

# %%
df['bedrooms'].value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33])

# %%
for i in df['bedrooms'].unique():
    mean=df['price'][df['bedrooms'] ==i].mean()
    print(f'num of bedrooms= {i} and mean = {mean}')
# Out:
# num of bedrooms= 3 and mean = 466232.07848127035
# num of bedrooms= 2 and mean = 401372.681884058
# num of bedrooms= 4 and mean = 635419.5042138913
# num of bedrooms= 5 and mean = 786599.8288569644
# num of bedrooms= 1 and mean = 317642.88442211057
# num of bedrooms= 6 and mean = 825520.6360294118
# num of bedrooms= 7 and mean = 951184.6578947369
# num of bedrooms= 0 and mean = 409503.8461538461
# num of bedrooms= 8 and mean = 1105076.923076923
# num of bedrooms= 9 and mean = 893999.8333333334
# num of bedrooms= 11 and mean = 520000.0
# num of bedrooms= 10 and mean = 819333.3333333334
# num of bedrooms= 33 and mean = 640000.0

# %%
df['price'].max()
# Out:
# 7700000.0

# %%
df['bedrooms'][df['price']==df['price'].max()]
# Out:
# 7252    6
# Name: bedrooms, dtype: int64

# %%
df['price'][df['sqft_above']==df['sqft_above'].max()]
# Out:
# 12777    2280000.0
# Name: price, dtype: float64

# %%
df['sqft_above'][df['price']==df['price'].max()]
# Out:
# 7252    8570
# Name: sqft_above, dtype: int64

# %%
df['sqft_above'].max()
# Out:
# 9410

# %%
df['price'][df['floors']==df['floors'].max()]
# Out:
# 875      1095000.0
# 10077     435000.0
# 11594     544000.0
# 14885     525000.0
# 15424     479000.0
# 18477    3300000.0
# 20308     525000.0
# 20772     563500.0
# Name: price, dtype: float64

# %%
df['floors'].value_counts()
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
df['floors']=df['floors'].astype('int')

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650       1
# 1      538000.0         3       2.25         2570      7242       2
# 2      180000.0         2       1.00          770     10000       1
# 3      604000.0         4       3.00         1960      5000       1
# 4      510000.0         3       2.00         1680      8080       1
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131       3
# 21609  400000.0         4       2.50         2310      5813       2
# 21610  402101.0         2       0.75         1020      1350       2
# 21611  400000.0         3       2.50         1600      2388       2
# 21612  325000.0         2       0.75         1020      1076       2
#
#        waterfront  view  grade  sqft_above  sqft_basement  yr_built  \
# 0               0     0      7        1180              0      1955
# ...

# %%
df['floors'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: floors
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  int64
# dtypes: int64(1)
# memory usage: 169.0 KB

# %%
df['price'].corr(df['grade'])
# Out:
# 0.6674342560202365

# %%
df['waterfront'].value_counts()
# Out:
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %%
df['view'].value_counts()
# Out:
# view
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: count, dtype: int64

# %%
df['sqft_living'].corr(df['price'])
# Out:
# 0.7020350546118002

# %%
df.corr()['price'].sort_values(ascending = False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.237211
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# Name: price, dtype: float64
